# %%
from abacat import Genome, config
from glob import glob
from os import path, system, stat
from COG import COGTranslator
from Bio import SeqIO
import pandas as pd

# %%
data_dir = "/home/vini/Bio/SynechococcusGT/"
genome_data = "/home/vini/data/prosyn/processing/genomic_fna/"

df = pd.read_csv("../data/tables/metadata_table.csv", sep=";")
df["No_genus"] = df.groupby('New_Genus')['New_Genus'].transform('count').map(int, na_action="ignore")

# %%
df["contigs_file"] = genome_data + df["filename"] + "_genomic.fna"

# %%
# Check everyone is here
for i in df["contigs_file"]:
    if not path.isfile(i):
        print(i)

# %%
df["abacat_file"] = df["contigs_file"].apply(lambda s: Genome(s))
# Out:
# 2020-03-24 22:11:28 - Contigs file set as /home/vini/data/prosyn/processing/genomic_fna/GCA_003990665.2_ASM399066v2_genomic.fna
# 2020-03-24 22:11:28 - Directory set as /home/vini/data/prosyn/processing/genomic_fna
# 2020-03-24 22:11:28 - Name set as GCA_003990665.2_ASM399066v2_genomic
# 2020-03-24 22:11:28 - Contigs file set as /home/vini/data/prosyn/processing/genomic_fna/GCA_002754935.1_ASM275493v1_genomic.fna
# 2020-03-24 22:11:28 - Directory set as /home/vini/data/prosyn/processing/genomic_fna
# 2020-03-24 22:11:28 - Name set as GCA_002754935.1_ASM275493v1_genomic
# 2020-03-24 22:11:28 - Contigs file set as /home/vini/data/prosyn/processing/genomic_fna/GCA_000011345.1_ASM1134v1_genomic.fna
# 2020-03-24 22:11:28 - Directory set as /home/vini/data/prosyn/processing/genomic_fna
# 2020-03-24 22:11:28 - Name set as GCA_000011345.1_ASM1134v1_genomic
# 2020-03-24 22:11:28 - Contigs file set as /home/vini/data/prosyn/processing/genomic_fna/GCA_003555505.1_ASM355550v1_genomic.fna
# ...

# %%
prodigal_dir = "/home/vini/data/prosyn/processing/prodigal/"
genes_dir = path.join(prodigal_dir, "genes")
proteins_dir = path.join(prodigal_dir, "proteins")
cds_dir = path.join(prodigal_dir, "cds")

# %%
def prodigal_files(Genome):
    Genome.files["prodigal"] = dict()
    for k, v, x in zip(("genes", "proteins", "cds"), (genes_dir, proteins_dir, cds_dir), (".fna", ".faa", ".gbk")):
        Genome.files["prodigal"][k] = path.join(v, Genome.name + f"_prodigal_{k}{x}" )

# %%
for genome in df["abacat_file"]:
    prodigal_files(genome)
    for k, v in genome.files["prodigal"].items():
        if not path.isfile(v):
            print(genome.name, v)

# %%
output_dir = "/home/vini/data/prosyn/processing/dmnd_cog/"

for genome in df["abacat_file"]:
    genome.files["dmnd_out"] = path.join(output_dir, genome.name + "_dmnd.out")
    genome.files["met_out"] = path.join(output_dir, genome.name + "_met.out")  # met = metabolism

# %%
def run_diamond(genome, db, out="dmnd"):
    query = genome.files["prodigal"]["proteins"]
    output = genome.files[f"{out}_out"]
    cmd = f"diamond blastp -q {query} \
            --db {db} -o {output} -f 6 \
            qseqid sseqid pident length \
            mismatch gapopen qstart qend \
            sstart send evalue bitscore score \
            -p 60 -k 1 -e 10e-6"
    system(cmd)
    if path.isfile(output):
        print(f"Processed {genome.name}.")
    else:
        print(cmd, "\n")

# %%
cog = "/home/vini/data/db/COG/prot2003-2014.fa.dmnd"
met = "../data/misc/genes/metabolism_genes.faa.dmnd"

# df["abacat_file"].apply(lambda s: run_diamond(s, db=cog))
# df["abacat_file"].apply(lambda s: run_diamond(s, db=met, out="met"))

# %%
# Getting gene names from metabolism database
records = SeqIO.to_dict(SeqIO.parse(met[:-5], "fasta"))

def get_gene_code(gene_id):
    output = records[gene_id]
    name = " ".join(output.description.split()[1:]).split(" OS")[0]
    code = output.description.split("GN=")[1].split()[0]
    return gene_id, name, code

# %%
def generate_met_df(met_out):
    met = pd.read_csv(met_out, sep="\t")
    met.columns = "qseqid sseqid pident length \
                mismatch gapopen qstart qend \
                sstart send evalue bitscore score".split()
    met = met.drop_duplicates(subset=("qseqid"))
    gene_df = met["sseqid"].apply(lambda s: get_gene_code(s))
    gene_df = pd.DataFrame(gene_df.tolist(), columns=("sseqid gene_name gene_code".split()))
    met = met.merge(gene_df, on="sseqid")
    return gene_df

# %%
met_table = pd.DataFrame({"name": []})
for object_ in df["abacat_file"]:
    if stat(object_.files["met_out"]).st_size == 0:
        pass
    else:
        object_.met_df = generate_met_df(object_.files["met_out"])
        met_row = pd.DataFrame({"gene_code": object_.met_df["gene_code"].value_counts()}).T
        met_row.insert(0, "name", object_.name)
        met_table = met_table.merge(met_row, how="outer")

# %%
met_table_ = met_table[[
    'name', 'phoB', 'phoR',
    'feoB', 'ptrA', 'glnA',
    'glsF', 'amt', 'nirA',
    'narB', 'ureC', 'cynS',
    'mtnD', 'gdhA', 'arsC'
]].copy()
met_table_["amt"] = met_table[["amt", "amtA", "amt1"]].sum(axis=1)
met_table_["glnA"] = met_table[["glnA", "glnA-2"]].sum(axis=1)
met_table_["name"].apply(lambda s: s)
met_table_ = met_table_.fillna(0)
met_table_["name"] = met_table_["name"].apply(lambda s: s.split("_genomic")[0])
met_table_.rename(columns={"name":"filename"}, inplace=True)
met_table_ = df.merge(met_table_, on="filename", how="outer").query(
    "\
    Completeness >= 50 &\
    Contamination <= 10 &\
    No_genus > 1\
    "
)

# %%
# met_table_gb = met_table_[met_table_["TypeSpecies"] == "yes"]
met_table_gb_mean = met_table_.groupby("New_Genus").mean().round(2)[['phoB', 'phoR', 'feoB',
        'ptrA', 'glnA', 'glsF', 'amt', 'nirA', 'narB', 'ureC', 'cynS', 'mtnD',
        'gdhA', 'arsC',]]  # gb stands for 'groupby'

# met_table_gb = met_table_[met_table_["TypeSpecies"] == "yes"]
met_table_gb = met_table_.groupby("New_Genus").sum()[['phoB', 'phoR', 'feoB',
        'ptrA', 'glnA', 'glsF', 'amt', 'nirA', 'narB', 'ureC', 'cynS', 'mtnD',
        'gdhA', 'arsC',]]  # gb stands for 'groupby'

# %%
met_table_gb["No_genus"] = df.query("Completeness >= 50 & Contamination <= 10 & No_genus > 1").groupby("New_Genus").mean()["No_genus"]

# %%
# met_table_gb.iloc[:, :-1].to_csv("../data/tables/Table_2.csv")

# %%
met_table_bin = pd.DataFrame((met_table_gb.values / met_table_gb.values))  # bin stands for binary, presence/absence
met_table_bin.index = met_table_gb.index
met_table_bin.columns = met_table_gb.columns
met_table_bin.fillna(0, inplace=True)
met_table_bin.loc["total"] = met_table_bin.sum()
# met_table_bin.to_csv(path.join(data_dir, "data/met_table_binary.csv"))

# %%
cog_dir = path.dirname(config.CONFIG["db"]["COG"])
cog_domains = pd.read_csv(
    path.join(cog_dir, "cog2003-2014.csv"), header=None)
cog_domains.columns = (
    "domain-id", "genome-name",
    "protein-id","protein-length",
    "domain-start", "domain-end",
    "COG-id", "membership-class", ""
)
cog_domains.drop_duplicates(subset="domain-id", inplace=True)
cog_domains.set_index("domain-id", inplace=True)
cogt = COGTranslator()

# %%
def get_COG_name(sseqid):
    """
    Provide a sseqid from diamond output and returns
    (COG-XXXX, genome_name, description, metabolism)
    """
    domain = int(sseqid.split("|")[1])
    row = cog_domains.loc[domain]
    COG_code = row["COG-id"]
    genome_name = row["genome-name"]
    description = cogt.name_from_code(COG_code)
    # metabolism = cogt.letter_from_code(COG_code)
    
    return (sseqid, COG_code, genome_name, description)#, metabolism)

# %%
def generate_dmnd_df(dmnd_out):
    dmnd = pd.read_csv(dmnd_out, sep="\t")
    dmnd.columns = "qseqid sseqid pident length \
                mismatch gapopen qstart qend \
                sstart send evalue bitscore score".split()
    dmnd = dmnd.drop_duplicates(subset=("qseqid"))
    COG_names = dmnd["sseqid"].apply(lambda s: get_COG_name(s))
    COG_names = pd.DataFrame(COG_names.tolist(), columns=("sseqid COG_code genome_name description".split()))
    dmnd = dmnd.merge(COG_names, on="sseqid")
    return dmnd

# %%
# COG_table = pd.DataFrame({"name": []})
# for object_ in df["abacat_file"]:
#     object_.dmnd_df = generate_dmnd_df(object_.files["dmnd_out"])
#     COG_row = pd.DataFrame({"COG_code": object_.dmnd_df["COG_code"].value_counts()}).T
#     COG_row.insert(0, "name", object_.name)
#     COG_table = COG_table.merge(COG_row, how="outer")

# %%
# COG_table.fillna(0, inplace=True)
# COG_table.loc["total"] = COG_table.sum()
# COG_table.loc["total", "name"] = "total"
# COG_table = COG_table.set_index("name")
# COG_table.to_csv("../data/tables/COG_table.csv")

# %%
COG_table = pd.read_csv("../data/tables/COG_table.csv")
COG_table.set_index("name", inplace=True)
COG_table = COG_table.iloc[:-1, :]

# %%
# COG_table_ = pd.DataFrame((COG_table.values / COG_table.values))
# COG_table_.index = COG_table.index
# COG_table_.columns = COG_table.columns
# COG_table_.fillna(0, inplace=True)
# COG_table_.loc["total"] = COG_table_.sum()
# COG_table_ = COG_table_.loc[:, (COG_table_ != 0).any(axis=0)]
# COG_table_.to_csv("../data/tables/COG_table_binary.csv")

# %%
COG_table_ = pd.read_csv("../data/tables/COG_table_binary.csv")
COG_table_.set_index("name", inplace=True)

# %%
filter_ = df.query(
    "Completeness >= 50 & \
     Contamination <= 10 & \
     No_genus > 1")["filename"] + "_genomic"
COG_table = COG_table.loc[filter_]
COG_table_ = COG_table_.loc[filter_]

# %%
df["proposed_name"] = df["New_Genus"] + " " + df["New_Species"] + " " + df["Strain"]
renaming_index = dict()
for k, v in zip((df["filename"] + "_genomic"), df["proposed_name"]):
    renaming_index[k] = v
renaming_columns = dict()
for k, v in zip(COG_table.columns, (cogt.name_from_code(i) for i in COG_table.columns)):
    renaming_columns[k] = v

# %%
COG_table.rename(
    index=renaming_index,
    columns=renaming_columns,
    inplace=True)
COG_table_.rename(
    index=renaming_index,
    columns=renaming_columns,
    inplace=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl



fig, ax = plt.subplots()

# define the colors
cmap = mpl.colors.ListedColormap(['b', 'w'])

# create a normalize object the describes the limits of
# each color
bounds = [0., 0.5, 1.]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)

# plot it
ax.imshow(COG_table_, interpolation='none', cmap=cmap, norm=norm)
